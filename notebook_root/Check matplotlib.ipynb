# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '1.4.2'

# %%
matplotlib.__file__
# Out:
# '/usr/local/lib/python2.7/site-packages/matplotlib/__init__.pyc'

# %%
matplotlib.get_configdir()
# Out:
# u'/Users/tnishibayashi/.matplotlib'

# %%
matplotlib.matplotlib_fname()
# Out:
# u'/Users/tnishibayashi/.matplotlib/matplotlibrc'

# %%
matplotlib.rcParams.get('font.family')
# Out:
# [u'Osaka']

# %%
matplotlib.matplotlib_fname()
# Out:
# u'/Users/tnishibayashi/.matplotlib/matplotlibrc'

# %%
import matplotlib.font_manager as fm
fm.findSystemFonts()
# Out:
# [u'/Library/Fonts/Microsoft/MS PGothic.ttf',
#  u'/Library/Fonts/Trebuchet MS Italic.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraBd.ttf',
#  u'/Library/Fonts/Hoefler Text Ornaments.ttf',
#  u'/Library/Fonts/Microsoft/Meiryo Bold Italic.ttf',
#  u'/Library/Fonts/MshtakanRegular.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraBI.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxisri.ttf',
#  u'/Library/Fonts/Osaka.ttf',
#  u'/Library/Fonts/Microsoft/Candara Italic.ttf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u660e\u671d Pro W3.otf',
#  u'/Library/Fonts/Verdana Bold.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luximb.ttf',
#  u'/Library/Fonts/AppleSDGothicNeo-UltraLight.otf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMBatnanBold.otf',
#  u'/Library/Fonts/Arial Unicode.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraSe.ttf',
#  u'/Library/Fonts/STIXSizThreeSymReg.otf',
#  u'/Library/Fonts/DIN Condensed Bold.ttf',
#  u'/Library/Fonts/Microsoft/Gill Sans MT.ttf',
#  u'/Library/Fonts/Microsoft/Gill Sans MT Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMKharput.otf',
#  u'/Library/Fonts/Microsoft/HGRSMP.TTF',
#  u'/Library/Fonts/Microsoft/himalaya.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraMoIt.ttf',
#  u'/Library/Fonts/Times New Roman.ttf',
#  u'/Library/Fonts/\u5137\u5b8b Pro.ttf',
#  u'/Library/Fonts/AppleSDGothicNeo-Heavy.otf',
#  u'/Library/Fonts/Arial.ttf',
#  u'/Library/Fonts/Microsoft/Constantia.ttf',
#  u'/Library/Fonts/AppleGothic.ttf',
#  u'/Library/Fonts/Microsoft/Cambria Bold.ttf',
#  u'/Library/Fonts/Microsoft/Palatino Linotype Bold.ttf',
#  u'/Library/Fonts/Yu Gothic Medium.otf',
#  u'/Library/Fonts/GujaratiMTBold.ttf',
#  u'/Library/Fonts/Microsoft/Meiryo Italic.ttf',
#  u'/Library/Fonts/Arial Narrow.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luximbi.ttf',
#  u'/System/Library/Fonts/AppleSDGothicNeo-Bold.otf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u4e38\u30b3\u3099 ProN W4.otf',
#  u'/Library/Fonts/NISC18030.ttf',
#  u'/Library/Fonts/MshtakanOblique.ttf',
#  u'/Library/Fonts/Microsoft/Times New Roman Italic.ttf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u660e\u671d Pro W6.otf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u89d2\u30b3\u3099 Std W8.otf',
#  u'/Library/Fonts/AppleMyungjo.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraMoBI.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraBd.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMMardinBold.otf',
#  u'/Library/Fonts/Microsoft/Arial Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMJerusalemOutline.otf',
#  u'/Library/Fonts/Microsoft/Candara Bold Italic.ttf',
#  u'/Library/Fonts/Microsoft/PMingLiU-ExtB.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luximri.ttf',
#  u'/Library/Fonts/Microsoft/Calibri Bold Italic.ttf',
#  u'/Library/Fonts/STIXIntDBol.otf',
#  u'/Library/Fonts/Apple LiSung Light.ttf',
#  u'/Library/Fonts/Microsoft/Corbel Bold Italic.ttf',
#  u'/Library/Fonts/DIN Alternate Bold.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraMono.ttf',
#  u'/Library/Fonts/Myanmar Sangam MN.ttf',
#  u'/Library/Fonts/STIXSizThreeSymBol.otf',
#  u'/Library/Fonts/Microsoft/MS Mincho.ttf',
#  u'/Library/Fonts/Courier New.ttf',
#  u'/Library/Fonts/Arial Narrow Bold Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMJerusalem.otf',
#  u'/Library/Fonts/Zapfino.ttf',
#  u'/Library/Fonts/Arial Narrow Bold.ttf',
#  u'/Library/Fonts/Times New Roman Italic.ttf',
#  u'/Library/Fonts/Krungthep.ttf',
#  u'/Library/Fonts/AppleSDGothicNeo-ExtraBold.otf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMAdiabene.otf',
#  u'/Library/Fonts/Microsoft/Times New Roman Bold Italic.ttf',
#  u'/Library/Fonts/Microsoft/monbaiti.ttf',
#  u'/Library/Fonts/Georgia.ttf',
#  u'/Library/Fonts/Microsoft/Candara Bold.ttf',
#  u'/Library/Fonts/STIXIntSmBol.otf',
#  u'/System/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u89d2\u30b3\u3099 ProN W6.otf',
#  u'/Library/Fonts/Trebuchet MS Bold.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMTurAbdin.otf',
#  u'/Library/Fonts/Microsoft/Constantia Bold.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraMoBd.ttf',
#  u'/Library/Fonts/Microsoft/Meiryo Bold.ttf',
#  u'/Library/Fonts/Microsoft/mingliu_hkscs.ttf',
#  u'/System/Library/Fonts/Apple Symbols.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMNisibinOutline.otf',
#  u'/Library/Fonts/Times New Roman Bold Italic.ttf',
#  u'/Library/Fonts/Webdings.ttf',
#  u'/Library/Fonts/Arial Narrow Italic.ttf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u89d2\u30b3\u3099 Pro W6.otf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMCtesiphon.otf',
#  u'/Library/Fonts/Microsoft/MingLiU-ExtB.ttf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u4e38\u30b3\u3099 Pro W4.otf',
#  u'/Library/Fonts/Microsoft/Arial Bold Italic.ttf',
#  u'/Library/Fonts/Pilgiche.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMMidyat.otf',
#  u'/System/Library/Fonts/Apple Braille Outline 8 Dot.ttf',
#  u'/Library/Fonts/Microsoft/Arial Bold.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraSe.ttf',
#  u'/Library/Fonts/Microsoft/Bookshelf Symbol 7.ttf',
#  u'/Library/Fonts/Nadeem.ttf',
#  u'/Library/Fonts/PlantagenetCherokee.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxirr.ttf',
#  u'/Library/Fonts/Times New Roman Bold.ttf',
#  u'/Library/Fonts/BiauKai.ttf',
#  u'/Library/Fonts/Microsoft/MS Gothic.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraIt.ttf',
#  u'/Library/Fonts/Microsoft/Brush Script.ttf',
#  u'/Library/Fonts/Microsoft/Corbel Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxisbi.ttf',
#  u'/Library/Fonts/Arial Bold Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/GohaTibebZemen.ttf',
#  u'/Library/Fonts/Microsoft/Tw Cen MT Bold Italic.ttf',
#  u'/Library/Fonts/Microsoft/Franklin Gothic Book Italic.ttf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u89d2\u30b3\u3099 Pro W3.otf',
#  u'/Library/Fonts/STIXVar.otf',
#  u'/Library/Fonts/Microsoft/Tw Cen MT Bold.ttf',
#  u'/Library/Fonts/STIXVarBol.otf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMMalankara.otf',
#  u'/Library/Fonts/Hiragino Sans GB W3.otf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMBatnan.otf',
#  u'/Library/Fonts/\u534e\u6587\u4eff\u5b8b.ttf',
#  u'/Library/Fonts/MshtakanBold.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraMoIt.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraMoBd.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraMono.ttf',
#  u'/Library/Fonts/Microsoft/Cambria Math.ttf',
#  u'/Library/Fonts/\u534e\u6587\u9ed1\u4f53.ttf',
#  u'/Library/Fonts/Microsoft/MS PMincho.ttf',
#  u'/Library/Fonts/STIXIntUpBol.otf',
#  u'/Library/Fonts/WawaTC-Regular.otf',
#  u'/Library/Fonts/Microsoft/MS Reference Sans Serif.ttf',
#  u'/Library/Fonts/Skia.ttf',
#  u'/Library/Fonts/STIXSizFiveSymReg.otf',
#  u'/Library/Fonts/Verdana.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxisbi.ttf',
#  u'/Library/Fonts/Microsoft/Corbel.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxisb.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMUrhoyBold.otf',
#  u'/Library/Fonts/Gurmukhi.ttf',
#  u'/Library/Fonts/Yu Gothic Bold.otf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraIt.ttf',
#  u'/System/Library/Fonts/Apple Color Emoji.ttf',
#  u'/Library/Fonts/Microsoft/Cambria Italic.ttf',
#  u'/Library/Fonts/Yu Mincho Demibold.otf',
#  u'/System/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u660e\u671d ProN W3.otf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxisr.ttf',
#  u'/Library/Fonts/Microsoft/Lucida Console.ttf',
#  u'/Library/Fonts/Arial Italic.ttf',
#  u'/Library/Fonts/Microsoft/SimSun.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxisb.ttf',
#  u'/System/Library/Fonts/LastResort.ttf',
#  u'/Library/Fonts/Microsoft/Perpetua.ttf',
#  u'/Library/Fonts/STIXNonUniBolIta.otf',
#  u'/Library/Fonts/Microsoft/Arial.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxirb.ttf',
#  u'/Library/Fonts/Georgia Italic.ttf',
#  u'/Library/Fonts/Microsoft/TaiLeb.ttf',
#  u'/Library/Fonts/Chalkduster.ttf',
#  u'/Library/Fonts/Courier New Bold Italic.ttf',
#  u'/Library/Fonts/WawaSC-Regular.otf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMTalada.otf',
#  u'/Library/Fonts/Microsoft/Verdana Bold.ttf',
#  u'/System/Library/Fonts/ZapfDingbats.ttf',
#  u'/Library/Fonts/Arial Rounded Bold.ttf',
#  u'/Library/Fonts/DevanagariMTBold.ttf',
#  u'/Library/Fonts/Microsoft/Verdana.ttf',
#  u'/Library/Fonts/DevanagariMT.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxirri.ttf',
#  u'/Library/Fonts/Microsoft/SimHei.ttf',
#  u'/Library/Fonts/Microsoft/Franklin Gothic Medium.ttf',
#  u'/Library/Fonts/PCmyoungjo.ttf',
#  u'/Library/Fonts/Microsoft/Calibri.ttf',
#  u'/Library/Fonts/AppleSDGothicNeo-Light.otf',
#  u'/Library/Fonts/AlBayan.ttf',
#  u'/Library/Fonts/Verdana Bold Italic.ttf',
#  u'/Library/Fonts/Microsoft/Franklin Gothic Medium Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraMoBI.ttf',
#  u'/Library/Fonts/\u5137\u9ed1 Pro.ttf',
#  u'/Library/Fonts/Hiragino Sans GB W6.otf',
#  u'/Library/Fonts/Kailasa.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMEdessa.otf',
#  u'/Library/Fonts/STIXIntSmReg.otf',
#  u'/Library/Fonts/AppleSDGothicNeo-Thin.otf',
#  u'/Library/Fonts/Kokonor.ttf',
#  u'/System/Library/Fonts/Geeza Pro Bold.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/GohaTibebZemen.otf',
#  u'/Library/Fonts/Verdana Italic.ttf',
#  u'/Library/Fonts/STIXGeneralBol.otf',
#  u'/System/Library/Fonts/Apple Braille.ttf',
#  u'/Library/Fonts/Microsoft/Constantia Italic.ttf',
#  u'/Library/Fonts/Microsoft/Constantia Bold Italic.ttf',
#  u'/Library/Fonts/InaiMathi.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/Vera.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMAntioch.otf',
#  u'/Library/Fonts/WeibeiTC-Bold.otf',
#  u'/Library/Fonts/Microsoft/Consolas Bold Italic.ttf',
#  u'/Library/Fonts/Microsoft/Cambria.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxirri.ttf',
#  u'/Library/Fonts/Microsoft/Perpetua Bold.ttf',
#  u'/Library/Fonts/STIXNonUni.otf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxirbi.ttf',
#  u'/Library/Fonts/Microsoft/Batang.ttf',
#  u'/Library/Fonts/Microsoft/Verdana Italic.ttf',
#  u'/Library/Fonts/Microsoft/Franklin Gothic Book.ttf',
#  u'/Library/Fonts/STIXIntDReg.otf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxirb.ttf',
#  u'/Library/Fonts/STIXNonUniIta.otf',
#  u'/Library/Fonts/Baghdad.ttf',
#  u'/Library/Fonts/STIXIntUpReg.otf',
#  u'/Library/Fonts/YuppySC-Regular.otf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luximb.ttf',
#  u'/Library/Fonts/Comic Sans MS Bold.ttf',
#  u'/Library/Fonts/Trebuchet MS.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMNisibin.otf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraBI.ttf',
#  u'/Library/Fonts/Courier New Bold.ttf',
#  u'/Library/Fonts/BigCaslon.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMJerusalemItalic.otf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMUrhoy.otf',
#  u'/Library/Fonts/Microsoft/Wingdings 2.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxirbi.ttf',
#  u'/Library/Fonts/Ayuthaya.ttf',
#  u'/Library/Fonts/AppleSDGothicNeo-SemiBold.otf',
#  u'/Library/Fonts/Herculanum.ttf',
#  u'/Library/Fonts/DecoTypeNaskh.ttf',
#  u'/Library/Fonts/Microsoft/Wingdings.ttf',
#  u'/System/Library/Fonts/Apple Braille Pinpoint 6 Dot.ttf',
#  u'/System/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u660e\u671d ProN W6.otf',
#  u'/System/Library/Fonts/Symbol.ttf',
#  u'/Library/Fonts/Microsoft/Corbel Bold.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxisr.ttf',
#  u'/Library/Fonts/Trebuchet MS Bold Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/VeraSeBd.ttf',
#  u'/Library/Fonts/\u534e\u6587\u7ec6\u9ed1.ttf',
#  u'/Library/Fonts/Microsoft/MingLiU_HKSCS-ExtB.ttf',
#  u'/Library/Fonts/AlBayanBold.ttf',
#  u'/Library/Fonts/Wingdings 2.ttf',
#  u'/Library/Fonts/HeadlineA.ttf',
#  u'/Library/Fonts/Microsoft/MS Reference Specialty.ttf',
#  u'/Library/Fonts/Tahoma.ttf',
#  u'/Library/Fonts/Brush Script.ttf',
#  u'/System/Library/Fonts/Keyboard.ttf',
#  u'/Library/Fonts/Microsoft/Gill Sans MT Bold.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/VeraSeBd.ttf',
#  u'/Library/Fonts/Microsoft/Lucida Sans Unicode.ttf',
#  u'/Library/Fonts/Microsoft/Palatino Linotype Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMJerusalemBold.otf',
#  u'/Library/Fonts/Microsoft/Palatino Linotype Bold Italic.ttf',
#  u'/Library/Fonts/STIXSizOneSymReg.otf',
#  u'/Library/Fonts/STIXIntUpSmReg.otf',
#  u'/Library/Fonts/Andale Mono.ttf',
#  u'/System/Library/Fonts/Geeza Pro.ttf',
#  u'/Library/Fonts/Khmer Sangam MN.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luximbi.ttf',
#  u'/Library/Fonts/Yu Mincho Medium.otf',
#  u'/Library/Fonts/Microsoft Sans Serif.ttf',
#  u'/Library/Fonts/Microsoft/Meiryo.ttf',
#  u'/Library/Fonts/STIXIntUpDBol.otf',
#  u'/Library/Fonts/Kai.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMQenNeshrin.otf',
#  u'/Library/Fonts/STIXGeneral.otf',
#  u'/Library/Fonts/Courier New Italic.ttf',
#  u'/Library/Fonts/Microsoft/Verdana Bold Italic.ttf',
#  u'/Library/Fonts/Arial Black.ttf',
#  u'/Library/Fonts/Microsoft/Consolas Italic.ttf',
#  u'/Library/Fonts/Microsoft/Tw Cen MT Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/OTF/SyrCOMMardin.otf',
#  u'/Library/Fonts/STIXGeneralItalic.otf',
#  u'/Library/Fonts/Silom.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/luxirr.ttf',
#  u'/Library/Fonts/MshtakanBoldOblique.ttf',
#  u'/Library/Fonts/Microsoft/taile.ttf',
#  u'/Library/Fonts/YuppyTC-Regular.otf',
#  u'/System/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u89d2\u30b3\u3099 ProN W3.otf',
#  u'/Library/Fonts/STIXSizFourSymReg.otf',
#  u'/Library/Fonts/Microsoft/Tw Cen MT.ttf',
#  u'/Library/Fonts/Apple Chancery.ttf',
#  u'/Library/Fonts/Microsoft/Times New Roman.ttf',
#  u'/Library/Fonts/Microsoft/msyi.ttf',
#  u'/Library/Fonts/Microsoft/Calibri Italic.ttf',
#  u'/usr/X11/lib/X11/fonts/TTF/Vera.ttf',
#  u'/Library/Fonts/Microsoft/Candara.ttf',
#  u'/Library/Fonts/Wingdings 3.ttf',
#  u'/Library/Fonts/Microsoft/MingLiU.ttf',
#  u'/Library/Fonts/STIXGeneralBolIta.otf',
#  u'/Library/Fonts/Microsoft/Gulim.ttf',
#  u'/Library/Fonts/Microsoft/Wingdings 3.ttf',
#  u'/Library/Fonts/STIXIntUpSmBol.otf',
#  u'/Library/Fonts/Lao Sangam MN.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/GohaTibebZemen.ttf',
#  u'/Library/Fonts/KufiStandardGK.ttf',
#  u'/Library/Fonts/Microsoft/Consolas.ttf',
#  u'/Library/Fonts/Microsoft/Times New Roman Bold.ttf',
#  u'/Library/Fonts/Microsoft/Perpetua Italic.ttf',
#  u'/Library/Fonts/STIXSizOneSymBol.otf',
#  u'/Library/Fonts/Microsoft/SimSun-ExtB.ttf',
#  u'/Library/Fonts/Microsoft/Palatino Linotype.ttf',
#  u'/Library/Fonts/Comic Sans MS.ttf',
#  u'/Library/Fonts/STIXSizTwoSymReg.otf',
#  u'/Library/Fonts/Hei.ttf',
#  u'/Library/Fonts/Microsoft/PMingLiU.ttf',
#  u'/Library/Fonts/WeibeiSC-Bold.otf',
#  u'/Library/Fonts/STIXSizFourSymBol.otf',
#  u'/Library/Fonts/Apple LiGothic Medium.ttf',
#  u'/Library/Fonts/Microsoft/Perpetua Bold Italic.ttf',
#  u'/Library/Fonts/Arial Bold.ttf',
#  u'/Library/Fonts/Microsoft/Cambria Bold Italic.ttf',
#  u'/Library/Fonts/Georgia Bold.ttf',
#  u'/Library/Fonts/Microsoft/Gabriola.ttf',
#  u'/Library/Fonts/Microsoft/Marlett.ttf',
#  u'/Library/Fonts/Microsoft/Calibri Bold.ttf',
#  u'/Library/Fonts/OsakaMono.ttf',
#  u'/Library/Fonts/Gungseouche.ttf',
#  u'/System/Library/Fonts/AppleSDGothicNeo-Regular.otf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luximr.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luxisri.ttf',
#  u'/System/Library/Fonts/Apple Braille Pinpoint 8 Dot.ttf',
#  u'/Library/Fonts/STIXSizTwoSymBol.otf',
#  u'/Library/Fonts/Wingdings.ttf',
#  u'/Library/Fonts/\u30d2\u30e9\u30ad\u3099\u30ce\u89d2\u30b3\u3099 StdN W8.otf',
#  u'/Library/Fonts/Impact.ttf',
#  u'/System/Library/Fonts/Apple Braille Outline 6 Dot.ttf',
#  u'/Library/Fonts/Tahoma Bold.ttf',
#  u'/Library/Fonts/STIXNonUniBol.otf',
#  u'/Library/Fonts/Georgia Bold Italic.ttf',
#  u'/Library/Fonts/STIXIntUpDReg.otf',
#  u'/Library/Fonts/Sathu.ttf',
#  u'/usr/X11R6/lib/X11/fonts/TTF/luximri.ttf',
#  u'/Library/Fonts/GujaratiMT.ttf',
#  u'/Library/Fonts/Microsoft/Gill Sans MT Bold Italic.ttf',
#  u'/Library/Fonts/Microsoft/Consolas Bold.ttf',
#  u'/Library/Fonts/AppleSDGothicNeo-Medium.otf',
#  u'/usr/X11/lib/X11/fonts/TTF/luximr.ttf']

# %%
X = np.linspace(-3, 3, 100)
plt.plot(X, np.exp(X))
plt.title(u'タイトル')
plt.xlabel(u'X軸です')
plt.ylabel(u'Y軸です')
